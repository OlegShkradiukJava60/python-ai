# %%
import numpy as np
import cv2
# diagonal
import matplotlib.pyplot as plt
height = 100
width = 100
img1 = np.zeros((width, height, 3),dtype=np.uint8)
for i in range(height):
    for j in range (width):
        if i == j: img1[i][j][0] = 255
plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
cv2.line(img1,(0, 0),(width, height), (255, 0, 0))
cv2.line(img1,(width, 0),(0, height), (255, 0, 0))
cv2.line(img1,(0, height // 2),(width, height // 2), (255, 0, 0))
cv2.circle(img1, (width // 2, height // 2), width // 3, (255, 0, 0), -1)
plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
# random colors
img2 = np.random.randint(0, 256, (50, 50, 3), dtype=np.uint8)
plt.axis('off')
plt.imshow(img2)
plt.show()

# %%
img3 = np.random.randint(0, 256, (50, 50), dtype=np.uint8)
plt.axis('off')
plt.imshow(img3, cmap="gray")
plt.show()

# %%
values = np.array([3, 5, 1, 7])
plt.plot(values)
plt.title("Simple plot line")
plt.show()

# %%
background = np.full((100, 100), 200, dtype=np.uint8)
plt.imshow(background, cmap="gray",vmin=0, vmax=255)
plt.axis('off')
plt.show()

# %%
import random
img4 = np.full((30, 30), 255, dtype=np.uint8)
for i in range(30):
    for j in range(30):
        img4[i][j] = 0 if random.randint(0, 2) else 220
plt.imshow(img4, cmap="gray", vmin=0, vmax=255) 
plt.show()

# %%
import time
from IPython.display import clear_output, display
img4 = np.full((30, 30), 255, dtype=np.uint8)
for t in range(20):
    for i in range(30):
        for j in range(30):
            img4[i][j] = 0 if random.randint(0, 2) else 220
    plt.imshow(img4, cmap="gray", vmin=0, vmax=255) 
    display(plt.gcf())
    clear_output(wait=True)
    time.sleep(0.4)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from IPython.display import clear_output, display

rows, cols = 30, 30
grid = np.random.choice([0, 1], size=(rows, cols), p=[
                        0.7, 0.3]).astype(np.uint8)

for t in range(20):
    plt.imshow(grid, cmap="gray", vmin=0, vmax=1)
    display(plt.gcf())
    clear_output(wait=True)
    time.sleep(0.1)

    new_grid = life_step(grid) # type: ignore

    if np.array_equal(new_grid, grid):
        print(f"Stopped at step {t}: stable configuration reached after {t + 1} steps.")
        break

    grid = new_grid.copy()
else:
    print("Simulation finished all 20 steps (no stable configuration found).")
# Out:
# Simulation finished all 20 steps (no stable configuration found).
